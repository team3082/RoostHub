# %%
import pandas as pd
pd.read_csv(r'C:\Users\emili\OneDrive\Desktop\Sttuff\roost_hub\match-data-2026-02-23 (1).csv')
# Out:
#    Match Number  Team Number Position Scouter Name  Auto L1 Climb  \
# 0             6         2227   redTop      No Name              1
# 1             6         2264   redTop      No Name              1
#
#    Auto Attempted Climb  Auto Used Depot  Auto Used Outpost  Auto Bump  \
# 0                     2                0                  1          4
# 1                     6                1                  3          3
#
#    Auto Trench  ... Teleop Trench         Teleop Shooting Times  End None  \
# 0            1  ...             3  0.366;1.159;1.592;1.96;1.264       Yes
# 1            4  ...             0                           NaN       Yes
#
#    End Park  End Shallow  End Deep  Disabled  Defense Rank  Driving Rank  \
# 0        No           No        No       NaN             0             0
# 1        No           No        No       NaN             0             0
#
#    Notes
# 0    Wow
# 1   Bhhb
#
# [2 rows x 29 columns]
